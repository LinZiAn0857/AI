# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, LeakyReLU, Conv2D
from keras.optimizers import RMSprop
from keras import backend as K
from matplotlib.pyplot import imshow
import numpy as np


(x_train, y_train), (x_test, y_test) = mnist.load_data()
num_classes=10

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Dense(20, activation=LeakyReLU(), input_shape=(784,)))
model.add(Dense(20, activation=LeakyReLU()))
model.add(Dense(10, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=10,
                    verbose=1,
                    validation_data=(x_test, y_test))

scores = model.evaluate(x_test, y_test)
print(scores[1])
# Out:
# 60000 train samples
# 10000 test samples
# /usr/local/lib/python3.6/dist-packages/keras/activations.py:235: UserWarning: Do not pass a layer instance (such as LeakyReLU) as the activation argument of another layer. Instead, advanced activation layers should be used just like any other layer in a model.
#   identifier=identifier.__class__.__name__))
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 20)                15700
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                210
# =================================================================
# Total params: 16,330
# Trainable params: 16,330
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.5205 - accuracy: 0.8582 - val_loss: 0.3017 - val_accuracy: 0.9148
# Epoch 2/10
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2829 - accuracy: 0.9188 - val_loss: 0.2598 - val_accuracy: 0.9257
# Epoch 3/10
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2456 - accuracy: 0.9297 - val_loss: 0.2286 - val_accuracy: 0.9337
# Epoch 4/10
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2197 - accuracy: 0.9379 - val_loss: 0.2087 - val_accuracy: 0.9396
# Epoch 5/10
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2001 - accuracy: 0.9435 - val_loss: 0.2009 - val_accuracy: 0.9415
# Epoch 6/10
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1858 - accuracy: 0.9469 - val_loss: 0.1874 - val_accuracy: 0.9452
# Epoch 7/10
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1738 - accuracy: 0.9500 - val_loss: 0.1846 - val_accuracy: 0.9465
# Epoch 8/10
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1643 - accuracy: 0.9526 - val_loss: 0.1751 - val_accuracy: 0.9510
# Epoch 9/10
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1569 - accuracy: 0.9545 - val_loss: 0.1645 - val_accuracy: 0.9514
# Epoch 10/10
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1501 - accuracy: 0.9559 - val_loss: 0.1659 - val_accuracy: 0.9529
# 10000/10000 [==============================] - 0s 45us/step
# 0.9528999924659729
