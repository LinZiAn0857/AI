# %%
from keras.datasets import mnist
from keras.layers import Dense, LSTM
from keras.utils import to_categorical
from keras.models import Sequential

#parameters for LSTM
#訓練參數
nb_lstm_outputs = 30  
nb_time_steps = 28  
nb_input_vector = 28 

#data preprocessing: tofloat32, normalization, one_hot encoding
#數據，分為訓練集和測試集
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
#將類向量轉換為二進制類矩陣
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

#build model
model = Sequential()
model.add(LSTM(units=nb_lstm_outputs, input_shape=(nb_time_steps, nb_input_vector)))
model.add(Dense(10, activation='softmax'))

#compile:loss, optimizer, metrics
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#train: epcoch, batch_size
model.fit(x_train, y_train, epochs=20, batch_size=128, verbose=1)

model.summary()

score = model.evaluate(x_test, y_test,batch_size=128, verbose=1)
print(score)
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step
# Epoch 1/20
# 60000/60000 [==============================] - 10s 163us/step - loss: 1.0250 - accuracy: 0.6767
# Epoch 2/20
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.3557 - accuracy: 0.8963
# Epoch 3/20
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.2396 - accuracy: 0.9316
# Epoch 4/20
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.1926 - accuracy: 0.9440
# Epoch 5/20
# 60000/60000 [==============================] - 10s 160us/step - loss: 0.1626 - accuracy: 0.9533
# Epoch 6/20
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.1464 - accuracy: 0.9574
# Epoch 7/20
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.1299 - accuracy: 0.9624
# Epoch 8/20
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.1199 - accuracy: 0.9653
# Epoch 9/20
# 60000/60000 [==============================] - 10s 160us/step - loss: 0.1098 - accuracy: 0.9679
# Epoch 10/20
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.1026 - accuracy: 0.9696
# Epoch 11/20
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0943 - accuracy: 0.9717
# Epoch 12/20
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0894 - accuracy: 0.9733
# Epoch 13/20
# 60000/60000 [==============================] - 9s 154us/step - loss: 0.0835 - accuracy: 0.9750
# Epoch 14/20
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0789 - accuracy: 0.9769
# Epoch 15/20
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0747 - accuracy: 0.9778
# Epoch 16/20
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0713 - accuracy: 0.9784
# Epoch 17/20
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0659 - accuracy: 0.9804
# Epoch 18/20
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0632 - accuracy: 0.9809
# Epoch 19/20
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0603 - accuracy: 0.9821
# Epoch 20/20
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0565 - accuracy: 0.9831
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 30)                7080
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                310
# =================================================================
# Total params: 7,390
# Trainable params: 7,390
# Non-trainable params: 0
# _________________________________________________________________
# 10000/10000 [==============================] - 0s 47us/step
# [0.07522619315125048, 0.9775999784469604]
