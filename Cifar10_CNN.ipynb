# %%
from keras.datasets import cifar10
#數據，分為訓練集和測試集
(x_train, y_train_), (x_test, y_test_) = cifar10.load_data()

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

#將類向量轉換為二進制類矩陣
from keras.utils import to_categorical
y_train = to_categorical(y_train_)
y_test = to_categorical(y_test_)

"""## Model Definition"""
#建立模型 使用Sequential（）
from keras.models import Sequential
model = Sequential()

from keras.layers import Conv2D, MaxPool2D, Flatten, Dense

model.add(Conv2D(filters=32, 
                kernel_size=(3, 3),
                activation='relu',
                input_shape=(32, 32, 3)))

model.add(MaxPool2D())

model.add(Conv2D(filters=64,
                kernel_size=(3, 3),
                activation='relu'))
model.add(MaxPool2D())

model.add(Flatten())
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])
#打印模型
print(model.summary())

"""## Fitting"""
#在生成的批次上擬合模型
history = model.fit(x_train, y_train, batch_size=50, epochs=15, verbose=1, validation_data=(x_test, y_test))

import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(history_dict['accuracy']) + 1)

plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                23050
# =================================================================
# Total params: 42,442
# Trainable params: 42,442
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 12s 245us/step - loss: 1.5040 - accuracy: 0.4634 - val_loss: 1.2482 - val_accuracy: 0.5636
# Epoch 2/15
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.1869 - accuracy: 0.5881 - val_loss: 1.1344 - val_accuracy: 0.6080
# Epoch 3/15
# 50000/50000 [==============================] - 6s 113us/step - loss: 1.0593 - accuracy: 0.6360 - val_loss: 1.0703 - val_accuracy: 0.6284
# Epoch 4/15
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.9799 - accuracy: 0.6622 - val_loss: 0.9952 - val_accuracy: 0.6592
# Epoch 5/15
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.9216 - accuracy: 0.6832 - val_loss: 0.9762 - val_accuracy: 0.6664
# Epoch 6/15
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.8760 - accuracy: 0.7003 - val_loss: 0.9391 - val_accuracy: 0.6833
# Epoch 7/15
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.8372 - accuracy: 0.7118 - val_loss: 0.9340 - val_accuracy: 0.6789
# Epoch 8/15
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.8030 - accuracy: 0.7245 - val_loss: 0.9366 - val_accuracy: 0.6848
# Epoch 9/15
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.7767 - accuracy: 0.7325 - val_loss: 0.9208 - val_accuracy: 0.6871
# Epoch 10/15
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.7523 - accuracy: 0.7432 - val_loss: 0.9178 - val_accuracy: 0.6895
# Epoch 11/15
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.7283 - accuracy: 0.7501 - val_loss: 0.9167 - val_accuracy: 0.6951
# Epoch 12/15
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.7074 - accuracy: 0.7564 - val_loss: 0.9036 - val_accuracy: 0.6984
# Epoch 13/15
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.6913 - accuracy: 0.7620 - val_loss: 0.9295 - val_accuracy: 0.6918
# Epoch 14/15
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.6758 - accuracy: 0.7692 - val_loss: 0.9224 - val_accuracy: 0.6915
# Epoch 15/15
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.6556 - accuracy: 0.7742 - val_loss: 0.9487 - val_accuracy: 0.6828
