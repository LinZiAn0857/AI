# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

import numpy as np
data = np.random.random((1000, 10)) #隨機產生1000筆資料，每筆資料1包含十個float數字
labels = np.random.randint(2, size=(1000, 1)) #隨機產生1000筆資料，每筆資料上限為2(意思就是0 或 1)
print(np.shape(data))
print(data[0])
print(np.shape(labels))
print(labels[0])

model = Sequential()#建造模型
model.add(Dense(32, activation='relu', input_dim=10))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(data, labels, epochs=10, batch_size=32)

score=model.evaluate(data, labels)
print(score[1])
# Out:
# Using TensorFlow backend.
# (1000, 10)
# [0.43302698 0.3767884  0.95537647 0.44167695 0.33598767 0.70642498
#  0.8741892  0.22286024 0.8495471  0.26502366]
# (1000, 1)
# [0]
# Epoch 1/10
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6966 - accuracy: 0.4870
# Epoch 2/10
# 1000/1000 [==============================] - 0s 71us/step - loss: 0.6950 - accuracy: 0.4930
# Epoch 3/10
# 1000/1000 [==============================] - 0s 81us/step - loss: 0.6942 - accuracy: 0.5130
# Epoch 4/10
# 1000/1000 [==============================] - 0s 81us/step - loss: 0.6932 - accuracy: 0.5030
# Epoch 5/10
# 1000/1000 [==============================] - 0s 89us/step - loss: 0.6929 - accuracy: 0.5210
# Epoch 6/10
# 1000/1000 [==============================] - 0s 81us/step - loss: 0.6925 - accuracy: 0.5190
# Epoch 7/10
# 1000/1000 [==============================] - 0s 82us/step - loss: 0.6917 - accuracy: 0.5260
# Epoch 8/10
# 1000/1000 [==============================] - 0s 81us/step - loss: 0.6911 - accuracy: 0.5260
# Epoch 9/10
# 1000/1000 [==============================] - 0s 82us/step - loss: 0.6913 - accuracy: 0.5250
# Epoch 10/10
# 1000/1000 [==============================] - 0s 81us/step - loss: 0.6909 - accuracy: 0.5380
# 1000/1000 [==============================] - 0s 52us/step
# 0.5389999747276306
